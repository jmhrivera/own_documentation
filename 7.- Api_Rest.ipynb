# %% [markdown]
# Hacer un llamado

# %%
import requests
response = requests.get("https://api.frankfurter.app/latest")
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Solicitar un json

# %%
import requests
response = requests.get("https://api.frankfurter.app/latest", )
print(response.json())
# Out:
# {'amount': 20.0, 'base': 'EUR', 'date': '2023-12-13', 'rates': {'AUD': 32.904, 'BGN': 39.116, 'BRL': 107.22, 'CAD': 29.288, 'CHF': 18.904, 'CNY': 154.85, 'CZK': 489.52, 'DKK': 149.13, 'GBP': 17.224, 'HKD': 168.58, 'HUF': 7618, 'IDR': 337240, 'ILS': 79.942, 'INR': 1799.27, 'ISK': 3014.0, 'JPY': 3142.6, 'KRW': 28457, 'MXN': 373.74, 'MYR': 101.53, 'NOK': 236.5, 'NZD': 35.382, 'PHP': 1209.86, 'PLN': 86.52, 'RON': 99.48, 'SEK': 225.54, 'SGD': 28.98, 'THB': 772.24, 'TRY': 626.8, 'USD': 21.574, 'ZAR': 411.74}}

# %%
import requests

params= {"from":"USD","to":"MXN", "amount":3}
response = requests.get("https://api.frankfurter.app/latest", params)
print(response.json())
# Out:
# {'amount': 3.0, 'base': 'USD', 'date': '2023-12-13', 'rates': {'MXN': 51.971}}

# %%
import requests

response = requests.get("https://api.frankfurter.app/latest")

print(response.headers['Server'])
print(response.headers['Content-Type'])
# print(response.headers['Content-Length'])
# Out:
# cloudflare
# application/json; charset=utf-8

# %%
import requests
import pprint

api_key= "yxCUr6v2GycFjmdILasrUHVNC45KTGV5"
params= {"apikey": api_key, "q":"09410"}


aw_location_url ="http://dataservice.accuweather.com/locations/v1/postalcodes/search"
aw_location_res = requests.get(aw_location_url, params)
print(aw_location_res )

for country in aw_location_res.json():
    pprint.pprint(country)
    print("___________________________________________")
# Out:
# <Response [200]>
# {'AdministrativeArea': {'CountryID': 'ES',
#                         'EnglishName': 'Castile and Leon',
#                         'EnglishType': 'Autonomous Community',
#                         'ID': 'CL',
#                         'Level': 1,
#                         'LocalizedName': 'Castile and Leon',
#                         'LocalizedType': 'Autonomous Community'},
#  'Country': {'EnglishName': 'Spain', 'ID': 'ES', 'LocalizedName': 'Spain'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'Alerts',
#               'DailyPollenForecast',
#               'ForecastConfidence',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Arandilla',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 2941.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 896.0}},
#                  'Latitude': 41.733,
#                  'Longitude': -3.433},
#  'IsAlias': False,
#  'Key': '70260_PC',
#  'LocalizedName': 'Arandilla',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'Europe', 'ID': 'EUR', 'LocalizedName': 'Europe'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CET',
#               'GmtOffset': 1.0,
#               'IsDaylightSaving': False,
#               'Name': 'Europe/Madrid',
#               'NextOffsetChange': '2024-03-31T01:00:00Z'},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'ES',
#                         'EnglishName': 'Castile and Leon',
#                         'EnglishType': 'Autonomous Community',
#                         'ID': 'CL',
#                         'Level': 1,
#                         'LocalizedName': 'Castile and Leon',
#                         'LocalizedType': 'Autonomous Community'},
#  'Country': {'EnglishName': 'Spain', 'ID': 'ES', 'LocalizedName': 'Spain'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'Alerts',
#               'DailyPollenForecast',
#               'ForecastConfidence',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Coruna Del Conde',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 3006.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 916.0}},
#                  'Latitude': 41.767,
#                  'Longitude': -3.383},
#  'IsAlias': False,
#  'Key': '70261_PC',
#  'LocalizedName': 'Coruna Del Conde',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'Europe', 'ID': 'EUR', 'LocalizedName': 'Europe'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CET',
#               'GmtOffset': 1.0,
#               'IsDaylightSaving': False,
#               'Name': 'Europe/Madrid',
#               'NextOffsetChange': '2024-03-31T01:00:00Z'},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'ES',
#                         'EnglishName': 'Castile and Leon',
#                         'EnglishType': 'Autonomous Community',
#                         'ID': 'CL',
#                         'Level': 1,
#                         'LocalizedName': 'Castile and Leon',
#                         'LocalizedType': 'Autonomous Community'},
#  'Country': {'EnglishName': 'Spain', 'ID': 'ES', 'LocalizedName': 'Spain'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'Alerts',
#               'DailyPollenForecast',
#               'ForecastConfidence',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Penaranda De Duero',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 2907.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 886.0}},
#                  'Latitude': 41.683,
#                  'Longitude': -3.483},
#  'IsAlias': False,
#  'Key': '70262_PC',
#  'LocalizedName': 'Penaranda De Duero',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'Europe', 'ID': 'EUR', 'LocalizedName': 'Europe'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CET',
#               'GmtOffset': 1.0,
#               'IsDaylightSaving': False,
#               'Name': 'Europe/Madrid',
#               'NextOffsetChange': '2024-03-31T01:00:00Z'},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'ES',
#                         'EnglishName': 'Castile and Leon',
#                         'EnglishType': 'Autonomous Community',
#                         'ID': 'CL',
#                         'Level': 1,
#                         'LocalizedName': 'Castile and Leon',
#                         'LocalizedType': 'Autonomous Community'},
#  'Country': {'EnglishName': 'Spain', 'ID': 'ES', 'LocalizedName': 'Spain'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'Alerts',
#               'DailyPollenForecast',
#               'ForecastConfidence',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Valverde',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 2911.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 887.0}},
#                  'Latitude': 41.717,
#                  'Longitude': -3.417},
#  'IsAlias': False,
#  'Key': '70263_PC',
#  'LocalizedName': 'Valverde',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'Europe', 'ID': 'EUR', 'LocalizedName': 'Europe'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CET',
#               'GmtOffset': 1.0,
#               'IsDaylightSaving': False,
#               'Name': 'Europe/Madrid',
#               'NextOffsetChange': '2024-03-31T01:00:00Z'},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'MX',
#                         'EnglishName': 'México City',
#                         'EnglishType': 'Federal District',
#                         'ID': 'CMX',
#                         'Level': 1,
#                         'LocalizedName': 'México City',
#                         'LocalizedType': 'Federal District'},
#  'Country': {'EnglishName': 'Mexico', 'ID': 'MX', 'LocalizedName': 'Mexico'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Aculco',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 7337.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 2236.0}},
#                  'Latitude': 19.367,
#                  'Longitude': -99.133},
#  'IsAlias': False,
#  'Key': '259021_PC',
#  'LocalizedName': 'Aculco',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'North America',
#             'ID': 'NAM',
#             'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CST',
#               'GmtOffset': -6.0,
#               'IsDaylightSaving': False,
#               'Name': 'America/Mexico_City',
#               'NextOffsetChange': None},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'MX',
#                         'EnglishName': 'México City',
#                         'EnglishType': 'Federal District',
#                         'ID': 'CMX',
#                         'Level': 1,
#                         'LocalizedName': 'México City',
#                         'LocalizedType': 'Federal District'},
#  'Country': {'EnglishName': 'Mexico', 'ID': 'MX', 'LocalizedName': 'Mexico'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Apatlaco Magdalena',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 7337.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 2236.0}},
#                  'Latitude': 19.367,
#                  'Longitude': -99.133},
#  'IsAlias': False,
#  'Key': '259020_PC',
#  'LocalizedName': 'Apatlaco Magdalena',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'North America',
#             'ID': 'NAM',
#             'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CST',
#               'GmtOffset': -6.0,
#               'IsDaylightSaving': False,
#               'Name': 'America/Mexico_City',
#               'NextOffsetChange': None},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'MX',
#                         'EnglishName': 'México City',
#                         'EnglishType': 'Federal District',
#                         'ID': 'CMX',
#                         'Level': 1,
#                         'LocalizedName': 'México City',
#                         'LocalizedType': 'Federal District'},
#  'Country': {'EnglishName': 'Mexico', 'ID': 'MX', 'LocalizedName': 'Mexico'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Jardines de Churubusco',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 7337.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 2236.0}},
#                  'Latitude': 19.367,
#                  'Longitude': -99.133},
#  'IsAlias': False,
#  'Key': '259022_PC',
#  'LocalizedName': 'Jardines de Churubusco',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'North America',
#             'ID': 'NAM',
#             'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CST',
#               'GmtOffset': -6.0,
#               'IsDaylightSaving': False,
#               'Name': 'America/Mexico_City',
#               'NextOffsetChange': None},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'MX',
#                         'EnglishName': 'México City',
#                         'EnglishType': 'Federal District',
#                         'ID': 'CMX',
#                         'Level': 1,
#                         'LocalizedName': 'México City',
#                         'LocalizedType': 'Federal District'},
#  'Country': {'EnglishName': 'Mexico', 'ID': 'MX', 'LocalizedName': 'Mexico'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'Magdalena Atlazolpa',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 7337.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 2236.0}},
#                  'Latitude': 19.367,
#                  'Longitude': -99.133},
#  'IsAlias': False,
#  'Key': '259023_PC',
#  'LocalizedName': 'Magdalena Atlazolpa',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'North America',
#             'ID': 'NAM',
#             'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CST',
#               'GmtOffset': -6.0,
#               'IsDaylightSaving': False,
#               'Name': 'America/Mexico_City',
#               'NextOffsetChange': None},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
# {'AdministrativeArea': {'CountryID': 'MX',
#                         'EnglishName': 'México City',
#                         'EnglishType': 'Federal District',
#                         'ID': 'CMX',
#                         'Level': 1,
#                         'LocalizedName': 'México City',
#                         'LocalizedType': 'Federal District'},
#  'Country': {'EnglishName': 'Mexico', 'ID': 'MX', 'LocalizedName': 'Mexico'},
#  'DataSets': ['AirQualityCurrentConditions',
#               'AirQualityForecasts',
#               'FutureRadar',
#               'MinuteCast',
#               'Radar'],
#  'EnglishName': 'San Jose Aculco',
#  'GeoPosition': {'Elevation': {'Imperial': {'Unit': 'ft',
#                                             'UnitType': 0,
#                                             'Value': 7337.0},
#                                'Metric': {'Unit': 'm',
#                                           'UnitType': 5,
#                                           'Value': 2236.0}},
#                  'Latitude': 19.367,
#                  'Longitude': -99.133},
#  'IsAlias': False,
#  'Key': '259024_PC',
#  'LocalizedName': 'San Jose Aculco',
#  'PrimaryPostalCode': '09410',
#  'Rank': 500,
#  'Region': {'EnglishName': 'North America',
#             'ID': 'NAM',
#             'LocalizedName': 'North America'},
#  'SupplementalAdminAreas': [],
#  'TimeZone': {'Code': 'CST',
#               'GmtOffset': -6.0,
#               'IsDaylightSaving': False,
#               'Name': 'America/Mexico_City',
#               'NextOffsetChange': None},
#  'Type': 'PostalCode',
#  'Version': 1}
# ___________________________________________
